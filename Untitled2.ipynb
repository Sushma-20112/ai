# %% [markdown]
# <a href="https://colab.research.google.com/github/Sushma-20112/ai/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install openai pandas nltk python-dotenv gspread oauth2client

# %%
import pandas as pd
import re
import nltk
import os
from nltk.corpus import stopwords
from openai import OpenAI
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
from google.colab import files
uploaded = files.upload()

# Suppose your file is "tickets_sample.csv"
df = pd.read_csv("tickets_sample.csv")
df.head()
# Out:
#      <input type="file" id="files-211d584e-5871-4e92-b699-cffa6b5ff1c2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-211d584e-5871-4e92-b699-cffa6b5ff1c2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
STOPWORDS = set(stopwords.words('english'))

def clean_text(text):
    text = str(text).lower()
    text = re.sub(r"http\S+", "", text)
    text = re.sub(r"[^a-z0-9\s]", " ", text)
    text = " ".join([w for w in text.split() if w not in STOPWORDS])
    return text

df["clean_text"] = df["description"].apply(clean_text)
df.head()
# Out:
#    ticket_id               title  \
# 0          1         Login issue
# 1          2     Payment failure
# 2          3           App crash
# 3          4      Password reset
# 4          5  Subscription query
#
#                                      description  \
# 0       Unable to login with my registered email
# 1        Payment not processing for premium plan
# 2                       App crashes after update
# 3  Forgot my password and reset link not working
# 4               Need to change subscription plan
#
#                            clean_text
# 0       unable login registered email
# 1     payment processing premium plan
# 2                  app crashes update
# 3  forgot password reset link working
# 4       need change subscription plan

# %%
import getpass
os.environ["OPENAI_API_KEY"] = getpass.getpass("Enter your OpenAI API key: ")

client = OpenAI(api_key=os.environ["OPENAI_API_KEY"])
# Out:
# Enter your OpenAI API key: ··········

# %%
# !pip install transformers torch

from transformers import pipeline
classifier = pipeline("zero-shot-classification",
                      model="facebook/bart-large-mnli")

text = "Unable to login with my registered email"
labels = ["Login Issue", "Payment Problem", "App Crash", "Subscription Query"]
result = classifier(text, labels)
print(result)
# Out:
# ...
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Device set to use cpu
# ...

# %%
df.to_csv("tickets_tagged.csv", index=False)
from google.colab import files
files.download("tickets_tagged.csv")

# %%
df.columns
# Out:
# Index(['ticket_id', 'title', 'description', 'clean_text'], dtype='object')

# %%
df.columns = df.columns.str.strip().str.lower()
print(df.columns)
# Out:
# Index(['ticket_id', 'title', 'description', 'clean_text'], dtype='object')

# %%
df["description"].head()
# Out:
# 0         Unable to login with my registered email
# 1          Payment not processing for premium plan
# 2                         App crashes after update
# 3    Forgot my password and reset link not working
# 4                 Need to change subscription plan
# Name: description, dtype: object

# %%
for i in range(len(df)):
    print(f"Ticket {i+1}: {df['description'][i]}")  # change 'description' if needed
    print(f" → Tags: {df['llm_tags'][i]}")
    print("-"*80)
# Out:
# Ticket 1: Unable to login with my registered email
#  → Tags: Login Issue
# --------------------------------------------------------------------------------
# Ticket 2: Payment not processing for premium plan
#  → Tags: Subscription Query
# --------------------------------------------------------------------------------
# Ticket 3: App crashes after update
#  → Tags: App Crash
# --------------------------------------------------------------------------------
# Ticket 4: Forgot my password and reset link not working
#  → Tags: Login Issue
# --------------------------------------------------------------------------------
# Ticket 5: Need to change subscription plan
#  → Tags: Payment Problem
# --------------------------------------------------------------------------------

# %%
df['llm_tags'] = df['clean_text'].apply(lambda x: classifier(x, labels)['labels'][0])
display(df.head())
# Out:
#    ticket_id               title  \
# 0          1         Login issue
# 1          2     Payment failure
# 2          3           App crash
# 3          4      Password reset
# 4          5  Subscription query
#
#                                      description  \
# 0       Unable to login with my registered email
# 1        Payment not processing for premium plan
# 2                       App crashes after update
# 3  Forgot my password and reset link not working
# 4               Need to change subscription plan
#
#                            clean_text            llm_tags
# 0       unable login registered email         Login Issue
# 1     payment processing premium plan  Subscription Query
# 2                  app crashes update           App Crash
# 3  forgot password reset link working         Login Issue
# 4       need change subscription plan     Payment Problem

# %%
df.columns = df.columns.str.strip().str.lower()  # clean column names

for i, row in df.iterrows():
    desc = row.get("ticket_description") or row.get("description") or row.get("issue") or row.get("text") or "N/A"
    tags = row.get("llm_tags", "N/A")
    print(f"Ticket {i+1}: {desc}")
    print(f" → Tags: {tags}")
    print("-"*80)
# Out:
# Ticket 1: Unable to login with my registered email
#  → Tags: Login Issue
# --------------------------------------------------------------------------------
# Ticket 2: Payment not processing for premium plan
#  → Tags: Subscription Query
# --------------------------------------------------------------------------------
# Ticket 3: App crashes after update
#  → Tags: App Crash
# --------------------------------------------------------------------------------
# Ticket 4: Forgot my password and reset link not working
#  → Tags: Login Issue
# --------------------------------------------------------------------------------
# Ticket 5: Need to change subscription plan
#  → Tags: Payment Problem
# --------------------------------------------------------------------------------
